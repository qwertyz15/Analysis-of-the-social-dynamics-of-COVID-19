# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Necessary libraries
import os 

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/")

# %%
import pandas as pd
df = pd.read_csv('Text3.csv')

# %%
df
# Out:
#                                                  Text_en                                            Text_bn
# 0      Highest number of Covid-19 deaths in a day. Ni...  একদিনে কোভিড -১৯ এর সর্বোচ্চ সংখ্যা। স্বাস্থ্য...
# 1      Thrown out of job, Tangail’s chamcham makers p...  চাকরি থেকে ছিটকে পড়ে, টাঙ্গাইলের চামচাম নির্ম...
# 2      Coping with Covid-19 Shutdown: 200 families re...  কোভিড -19 শাটডাউন মোকাবেলা: 200 পরিবার উদ্যানে...
# 3      7 family members, 4 police personnel test posi...  বগুড়ার কোভিড -১৯ এর জন্য পরিবারের family সদস্...
# 4      Coronavirus: Health ministry issues 13 directi...  করোনাভাইরাস: স্বাস্থ্য মন্ত্রনালয় সরকারি কর্ম...
# ...                                                  ...                                                ...
# 15560  The number of victims and deaths is increasing...  লাফিয়ে বাড়ছে আক্রান্ত ও মৃতের সংখ্যা| চীনে করো...
# 15561  India returns passengers in fear of coronaviru...  করোনাভাইরাস আতঙ্কে যাত্রী ফেরত দিয়েছে ভারত| কর...
# ...

# %%
contractions = { 
"বি.দ্র ": "বিশেষ দ্রষ্টব্য",
"ড.": "ডক্টর",
"ডা.": "ডাক্তার",
"ইঞ্জি:": "ইঞ্জিনিয়ার",
"রেজি:": "রেজিস্ট্রেশন",
"মি.": "মিস্টার",
"মু.": "মুহাম্মদ",
"মো.": "মোহাম্মদ",
}

# %%
lem = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQS1OdkDB3mqrFQCg5N3NEtlsV3a4B-9-B06dMknPXxIVhZb8RK1Ebr8B-xLq0yFg/pub?output=csv')
lem
# Out:
#                   word      lemmitize
# 0            স্বাস্থ্য      স্বাস্থ্য
# 1          করোনাভাইরাস    করোনাভাইরাস
# 2              পরীক্ষা        পরীক্ষা
# 3            হাসপাতালে       হাসপাতাল
# 4             বলেছিলেন       বলেছিলেন
# ...                ...            ...
# 80688      চার্চপ্রধান    চার্চপ্রধান
# 80689        গুণকীর্তন      গুণকীর্তন
# 80690       প্রার্থনায়      প্রার্থনা
# 80691  প্রার্থনাকারীরা  প্রার্থনাকারী
# 80692          যন্ত্রও         যন্ত্র
#
# [80693 rows x 2 columns]

# %%
c1 = lem['word'].tolist()
c2 = lem['lemmitize'].tolist()
c = dict(zip(c1, c2))

# %%
contractions = c.copy()

# %%
stopwords = pd.read_csv('http://bit.ly/bnstopwords',encoding = 'utf8')
stopwords = stopwords['StopWords'].tolist()

# %%
len(stopwords)
# Out:
# 837

# %%
import nltk
import re
import string
def clean_text(text):
    if True:
        text = str(text)
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(str(contractions[word]))
            else:
                new_text.append(word)
        
        text = " ".join(new_text)
    # Format words and remove unwanted characters
    whitespace = re.compile(u"[\s\u0020\u00a0\u1680\u180e\u202f\u205f\u3000\u2000-\u200a]+", re.UNICODE)
    bangla_digits = u"[\u09E6\u09E7\u09E8\u09E9\u09EA\u09EB\u09EC\u09ED\u09EE\u09EF]+"
    english_chars = u"[a-zA-Z0-9]"
    punc = u"[(),$%^&*+={}\[\]:\"|\'\~`<>/,¦!?½£¶¼©⅐⅑⅒⅓⅔⅕⅖⅗⅘⅙⅚⅛⅜⅝⅞⅟↉¤¿º;-]+"
    bangla_fullstop = u"\u0964"     #bangla fullstop(dari)
    punctSeq   = u"['\"“”‘’]+|[.?!,…]+|[:;]+"
    
    text = re.sub(bangla_digits, " ", text)
    text = re.sub(punc, " ", text)
    text = re.sub(english_chars, " ", text)
    text = re.sub(bangla_fullstop, " ", text)
    text = re.sub(punctSeq, " ", text)
    text = whitespace.sub(" ", text).strip()
    
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;‘:‘ ’', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]। ,', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r"[\@$#%~+-\.\'।\"]"," ",text)
    text = re.sub(r"(?m)^\s+", "", text)
    text = re.sub("[()]","",text)
    text = re.sub("[‘’]","",text)
    text = re.sub("[!]","",text)
    text = re.sub("[/]","",text)
    text = re.sub("[:]","",text)
    text= re.sub('\ |\?|\.|\!|\/|\;|\:', ' ',text)
    text= text.strip("/")
  
      
    return text

# %%
df['text_en_clean'] = df['Text_bn'].apply(clean_text)

# %%
df
# Out:
#                                                  Text_en  ...                                      text_en_clean
# 0      Highest number of Covid-19 deaths in a day. Ni...  ...  একদিন কোভিড এর সর্বোচ্চ সংখ্যা স্বাস্থ্য সেবা ...
# 1      Thrown out of job, Tangail’s chamcham makers p...  ...  চাকরি থেকে ছিটকে পড়ে টাঙ্গাইল চামচাম নির্মাতা...
# 2      Coping with Covid-19 Shutdown: 200 families re...  ...  কোভিড শাটডাউন মোকাবেলা পরিবার উদ্যান সুবিধা অর...
# 3      7 family members, 4 police personnel test posi...  ...  বগুড়া কোভিড এর জন্য পরিবার সদস্য জন পুলিশ সদস...
# 4      Coronavirus: Health ministry issues 13 directi...  ...  করোনাভাইরাস স্বাস্থ্য মন্ত্রনালয় সরকারি কর্মক...
# ...                                                  ...  ...                                                ...
# 15560  The number of victims and deaths is increasing...  ...  লাফিয় বাড়ছে আক্রান্ত ও মৃতের সংখ্যা চীনে করোনা...
# ...

# %%
def clean_text2(text):
  text = str(text)
  text = text.split() 
  resultwords  = [word for word in text if word not in stopwords]
  resultwords  = [word for word in text if len(word) > 5]
  result = ' '.join(resultwords)
  
  return result

# %%
df['text_en_clean_2'] = df['text_en_clean'].apply(clean_text2)

# %%
df
# Out:
#                                                  Text_en  ...                                    text_en_clean_2
# 0      Highest number of Covid-19 deaths in a day. Ni...  ...  সর্বোচ্চ সংখ্যা স্বাস্থ্য অধিদপ্তর মহাপরিচালক ...
# 1      Thrown out of job, Tangail’s chamcham makers p...  ...  টাঙ্গাইল চামচাম নির্মাতা প্রাদুর্ভাব লকডাউন বি...
# 2      Coping with Covid-19 Shutdown: 200 families re...  ...  শাটডাউন মোকাবেলা পরিবার উদ্যান সুবিধা মাসব্যাপ...
# 3      7 family members, 4 police personnel test posi...  ...  বগুড়া পরিবার পজিটিভ পরীক্ষা করেছেন কমপক্ষ বোগ...
# 4      Coronavirus: Health ministry issues 13 directi...  ...  করোনাভাইরাস স্বাস্থ্য মন্ত্রনালয় সরকারি কর্মক...
# ...                                                  ...  ...                                                ...
# 15560  The number of victims and deaths is increasing...  ...  আক্রান্ত সংখ্যা করোনাভাইরাসের সংক্রমণ নজিরবিহী...
# ...

# %%
# !pip install bangla-stemmer

# %%
from bangla_stemmer.stemmer import stemmer

def clean_text3(text):
  text = str(text)
  stmr = stemmer.BanglaStemmer()
  stm = stmr.stem(text)
  
  return stm

# %%
df['text_en_clean_3'] = df['text_en_clean_2'].apply(clean_text3)
# Out:
# Streaming output truncated to the last 5000 lines.
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied third rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# applied fourth rules..
# applied first rules..
# applied second rules..
# ...

# %%
df
# Out:
#                                                  Text_en  ...                                    text_en_clean_3
# 0      Highest number of Covid-19 deaths in a day. Ni...  ...  সর্বোচ্চ সংখ্যা স্বাস্থ্য অধিদপ্তর মহাপরিচালক ...
# 1      Thrown out of job, Tangail’s chamcham makers p...  ...  টাঙ্গাইল চামচাম নির্মাতা প্রাদুর্ভাব লকডাউন বি...
# 2      Coping with Covid-19 Shutdown: 200 families re...  ...  শাটডাউন মোকাবেলা পরিবার উদ্যান সুবিধা মাসব্যাপ...
# 3      7 family members, 4 police personnel test posi...  ...  বগুড়া পরিবার পজিটিভ পরীক্ষা করেছেন কমপক্ষ বোগ...
# 4      Coronavirus: Health ministry issues 13 directi...  ...  করোনাভাইরাস স্বাস্থ্য মন্ত্রনালয় সরকারি কর্মক...
# ...                                                  ...  ...                                                ...
# 15560  The number of victims and deaths is increasing...  ...  আক্রান্ত সংখ্যা করোনাভাইরাসের সংক্রমণ নজিরবিহী...
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
  
import string 
from nltk.stem.wordnet import WordNetLemmatizer
import nltk
nltk.download('wordnet')
import warnings
warnings.simplefilter('ignore')
from itertools import chain
bengali_stop_words = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSPT8tmOhGa8G3uykbmYiGNPm8uE2mxiPiak4FHvbEWCwZHMg5xvD4Nun3Hxfo3Hf-_WO2RJvc6bqZh/pub?output=csv')
stop_words = bengali_stop_words['StopWords'].tolist()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    cleanText = str(text)
    cleanText = ' '.join([word for word in cleanText.split() if word not in stop_words])
    cleanText = ''.join(ch for ch in cleanText if ch not in exclude)
    cleanText = ' '.join([lemma.lemmatize(word) for word in cleanText.split()])
    cleanText = ' '.join([word for word in cleanText.split() if len(word) > 5])
    
    return cleanText.split()

df['text_en_clean_4'] = df['text_en_clean_3'].apply(clean)

# %%
df
# Out:
#                                                  Text_en  ...                                    text_en_clean_4
# 0      Highest number of Covid-19 deaths in a day. Ni...  ...  [সর্বোচ্চ, স্বাস্থ্য, অধিদপ্তর, মহাপরিচালক, ডি...
# 1      Thrown out of job, Tangail’s chamcham makers p...  ...  [টাঙ্গাইল, চামচাম, নির্মাতা, প্রাদুর্ভাব, লকডা...
# 2      Coping with Covid-19 Shutdown: 200 families re...  ...  [শাটডাউন, মোকাবেলা, পরিবার, উদ্যান, সুবিধা, মা...
# 3      7 family members, 4 police personnel test posi...  ...  [বগুড়া, পরিবার, পজিটিভ, পরীক্ষা, কমপক্ষ, বোগু...
# 4      Coronavirus: Health ministry issues 13 directi...  ...  [করোনাভাইরাস, স্বাস্থ্য, মন্ত্রনালয়, সরকারি, ...
# ...                                                  ...  ...                                                ...
# 15560  The number of victims and deaths is increasing...  ...  [সংক্রমণ, নজিরবিহীন, প্রতিরোধমূলক, ব্যবস্থা, স...
# ...

# %%
df_stemmed_bn = df.copy()

# %%
df_stemmed_bn
# Out:
#                                                  Text_en  ...                                    text_en_clean_4
# 0      Highest number of Covid-19 deaths in a day. Ni...  ...  [সর্বোচ্চ, স্বাস্থ্য, অধিদপ্তর, মহাপরিচালক, ডি...
# 1      Thrown out of job, Tangail’s chamcham makers p...  ...  [টাঙ্গাইল, চামচাম, নির্মাতা, প্রাদুর্ভাব, লকডা...
# 2      Coping with Covid-19 Shutdown: 200 families re...  ...  [শাটডাউন, মোকাবেলা, পরিবার, উদ্যান, সুবিধা, মা...
# 3      7 family members, 4 police personnel test posi...  ...  [বগুড়া, পরিবার, পজিটিভ, পরীক্ষা, কমপক্ষ, বোগু...
# 4      Coronavirus: Health ministry issues 13 directi...  ...  [করোনাভাইরাস, স্বাস্থ্য, মন্ত্রনালয়, সরকারি, ...
# ...                                                  ...  ...                                                ...
# 15560  The number of victims and deaths is increasing...  ...  [সংক্রমণ, নজিরবিহীন, প্রতিরোধমূলক, ব্যবস্থা, স...
# ...

# %%
import pickle
df_stemmed_bn.to_pickle('df_stemmed_bn.pkl')
