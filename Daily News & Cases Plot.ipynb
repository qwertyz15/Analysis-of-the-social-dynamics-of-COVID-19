# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')

# Import Necessary libraries
import os 

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

data = pd.read_csv('/content/drive/My Drive/Final Dataset NEWSPAPERBD.csv',parse_dates=['Publish Date'])

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRjNbbMYoyaSCDMXv5bSTd3Q6Cel7vvkzvOfJ4k-ZSrvv3p-Cl26Y1N2XcIVyHUGrtyhv4rDd7ViVdo/pub?output=csv')

# %%
df
# Out:
#            Date  Daily News  Daily Cases  Daily Death
# 0    2020-01-21           1            0            0
# 1    2020-01-22           2            0            0
# 2    2020-01-23           0            0            0
# 3    2020-01-24           0            0            0
# 4    2020-01-25           6            0            0
# ..          ...         ...          ...          ...
# 115  2020-05-15         320         1202           15
# 116  2020-05-16        2017          930           16
# 117  2020-05-17          48         1273           14
# 118  2020-05-18          55         1602           21
# 119  2020-05-19          64         1251           21
#
# [120 rows x 4 columns]

# %%
df = df[:-4]

# %%
df['Date'] = pd.to_datetime(df['Date'], utc=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         116 non-null    datetime64[ns]
#  1   Daily News   116 non-null    int64
#  2   Daily Cases  116 non-null    int64
#  3   Daily Death  116 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 3.8 KB

# %%
df
# Out:
#           Date  Daily News  Daily Cases  Daily Death
# 0   2020-01-21           1            0            0
# 1   2020-01-22           2            0            0
# 2   2020-01-23           0            0            0
# 3   2020-01-24           0            0            0
# 4   2020-01-25           6            0            0
# ..         ...         ...          ...          ...
# 111 2020-05-11         214         1034           11
# 112 2020-05-12         159          969           11
# 113 2020-05-13         127         1162           19
# 114 2020-05-14         132         1041           14
# 115 2020-05-15         320         1202           15
#
# [116 rows x 4 columns]

# %%
df = df.set_index('Date')

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(df.index, df['Daily News'], label='Daily News',color = 'green')
plt.bar(df.index, df['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(df.index, df['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases (21 January 2020 - 19 May 2020)')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot01.png')

plt.show()

# %%
january = df['2020-01']

# %%
january
# Out:
#             Daily News  Daily Cases  Daily Death
# Date
# 2020-01-21           1            0            0
# 2020-01-22           2            0            0
# 2020-01-23           0            0            0
# 2020-01-24           0            0            0
# 2020-01-25           6            0            0
# 2020-01-26          11            0            0
# 2020-01-27          10            0            0
# 2020-01-28           9            0            0
# 2020-01-29          13            0            0
# 2020-01-30           6            0            0
# 2020-01-31           9            0            0

# %%
february = df['2020-02']
february
# Out:
#             Daily News  Daily Cases  Daily Death
# Date
# 2020-02-01          13            0            0
# 2020-02-02           1            0            0
# 2020-02-03          11            0            0
# 2020-02-04           8            0            0
# 2020-02-05          19            0            0
# 2020-02-06          29            0            0
# 2020-02-07          21            0            0
# 2020-02-08          42            0            0
# 2020-02-09          26            0            0
# 2020-02-10          27            0            0
# 2020-02-11          23            0            0
# 2020-02-12          29            0            0
# 2020-02-13          35            0            0
# 2020-02-14          19            0            0
# 2020-02-15          30            0            0
# 2020-02-16          23            0            0
# 2020-02-17          30            0            0
# 2020-02-18          21            0            0
# ...

# %%
march = df['2020-03']

# %%
april = df['2020-04']

# %%
may = df['2020-05']

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(january.index, january['Daily News'], label='Daily News',color = 'green')
plt.bar(january.index, january['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(january.index, january['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases of January 2020')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot02.png')

plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(february.index, february['Daily News'], label='Daily News',color = 'green')
plt.bar(february.index, february['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(february.index, february['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases of February 2020')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot03.png')

plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(march.index, march['Daily News'], label='Daily News',color = 'green')
plt.bar(march.index, march['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(march.index, march['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases of March 2020')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot04.png')

plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(april.index, april['Daily News'], label='Daily News',color = 'green')
plt.bar(april.index, april['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(april.index, april['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases of April 2020')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot05.png')

plt.show()

# %%
from matplotlib import pyplot as plt

plt.style.use("fivethirtyeight")
fig, ax1 = plt.subplots(1,1, figsize=(21,12))
plt.plot(may.index, may['Daily News'], label='Daily News',color = 'green')
plt.bar(may.index, may['Daily Cases'], label='Daily Cases',color = 'blue')
plt.bar(may.index, may['Daily Death'], label='Daily Death',color = 'red')

plt.xlabel('Date')
plt.ylabel('Counts')
plt.title('Daily News & Cases of May 2020')
plt.xticks(rotation=90)

plt.legend()

plt.tight_layout()

plt.savefig('plot06.png')

plt.show()
